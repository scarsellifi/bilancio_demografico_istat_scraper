# %%
import re
import mechanize
import urllib2
from bs4 import BeautifulSoup
import pandas as pd

# %%
anni = [2013, 2014, 2015]

mesi = ((1, "gennaio"), (2, "febbraio"), (3, "marzo"), (4, "aprile"), (5, "maggio"), (6,"giugno"), (7, "luglio"), (8, "agosto"),
            (9, "settembre"), (10, "ottobre"), (11, "novembre"), (12, "dicembre"))

def scarica_bilancio_demografico(anno, mese):
    dati_html = urllib2.urlopen("http://demo.istat.it/bilmens" + str(anno) + "gen/query1.php?lingua=ita&Pro=84&allrp=2&periodo=" + str(mese[0]) + "&submit=Tavola")
    dati_testo = dati_html.read()
    
    if dati_testo != '<H2>I dati richiesti non sono disponibili</H2><br><P><H4>Comune non rispondente o fuori standard</H4><P>':
        pass
    else:
        return '<H2>I dati richiesti non sono disponibili</H2><br><P><H4>Comune non rispondente o fuori standard</H4><P>' 
        
        
    soup = BeautifulSoup(dati_testo)
    tabella = soup.find_all("table")[1]
    row = 0
    
    data = {}
    for item in tabella.find_all("tr"):
        data[row] = []
        for item_lev2 in item.find_all("td"):
            data[row].append(item_lev2.text)
        row = row + 1
    
    for item in data.keys():
        if len(data[item]) != 11:
            #print item
            #print data[item]
            del data[item]

    dataframe = pd.DataFrame(data)
    dataframe.set_index(dataframe[0], inplace = True)
    dataframe.columns = dataframe.loc["Regioni"]
    
    dataframe.drop(["CodiceRegione","Regioni"] , axis = 0, inplace = True)
    dataframe.drop("Regioni" , axis = 1, inplace = True)
    dataframe = dataframe.applymap(lambda x: float(x))
    
    risultati = {}
    risultati["database"] = dataframe
    risultati["totale"] = dataframe.iloc[:,0:20]
    risultati["maschi"] = dataframe.iloc[:,20:40]
    risultati["femmine"] = dataframe.iloc[:,20:40]
    
    return risultati

# %%
database = {}

for anno in anni:
    database[anno] = {}
    for mese in mesi:
        database[anno][mese[0]] = scarica_bilancio_demografico(anno, mese)

# %%
Isem2015= (database[2015][1]["totale"] + 
           database[2015][2]["totale"] +
           database[2015][3]["totale"] +
           database[2015][4]["totale"] +
           database[2015][5]["totale"] +
           database[2015][6]["totale"])

Isem2014= (database[2014][1]["totale"] + 
           database[2014][2]["totale"] +
           database[2014][3]["totale"] +
           database[2014][4]["totale"] +
           database[2014][5]["totale"] +
           database[2014][6]["totale"])

# %%
Isem2015 / Isem2014 * 100 - 100
# Out:
# Regioni                                          Piemonte  \
# 0
# Popolazioneinizio periodo                       -0.338386
# Nati Vivi                                       -5.008934
# Morti                                           10.957292
# SaldoNaturale                                   41.738432
# Iscritti                                        -5.960442
# Cancellati                                      -2.314202
# Saldomigratorio e per altri motivi             -93.288815
# Unità inpiù/menodovute avariazioniterritoriali        NaN
# Popolazionefine periodo                         -0.362630
#
# Regioni                                         Valle d'Aosta/Vallée d'Aoste  \
# 0
# Popolazioneinizio periodo                                          -0.368887
# Nati Vivi                                                         -13.368984
# Morti                                                              18.475073
# SaldoNaturale                                                     166.115702
# Iscritti                                                           -4.569563
# Cancellati                                                          4.027113
# Saldomigratorio e per altri motivi                                373.684211
# Unità inpiù/menodovute avariazioniterritoriali                           NaN
# Popolazionefine periodo                                            -0.422665
#
# Regioni                                          Lombardia  \
# 0
# Popolazioneinizio periodo                         0.160739
# Nati Vivi                                        -2.041544
# Morti                                            10.332855
# SaldoNaturale                                   123.990395
# Iscritti                                        -13.123556
# Cancellati                                      -10.721189
# Saldomigratorio e per altri motivi              -40.274673
# Unità inpiù/menodovute avariazioniterritoriali         NaN
# Popolazionefine periodo                           0.140708
#
# Regioni                                         Trentino-Alto Adige  \
# 0
# Popolazioneinizio periodo                                  0.320918
# Nati Vivi                                                  0.909271
# Morti                                                      9.842863
# SaldoNaturale                                            -84.905660
# Iscritti                                                   0.850254
# Cancellati                                                 5.515538
# Saldomigratorio e per altri motivi                       -56.635672
# Unità inpiù/menodovute avariazioniterritoriali                  NaN
# Popolazionefine periodo                                    0.303820
#
# Regioni                                             Veneto  \
# 0
# Popolazioneinizio periodo                        -0.061890
# Nati Vivi                                        -0.993995
# Morti                                            10.339194
# SaldoNaturale                                    65.830165
# Iscritti                                         -4.649780
# Cancellati                                        2.222254
# Saldomigratorio e per altri motivi             -146.477638
# Unità inpiù/menodovute avariazioniterritoriali         NaN
# Popolazionefine periodo                          -0.087628
#
# Regioni                                         Friuli-Venezia Giulia  \
# 0
# Popolazioneinizio periodo                                   -0.247743
# Nati Vivi                                                   -6.204710
# Morti                                                       12.301876
# SaldoNaturale                                               45.509955
# Iscritti                                                   -10.845874
# Cancellati                                                  -1.778556
# Saldomigratorio e per altri motivi                        -113.855035
# Unità inpiù/menodovute avariazioniterritoriali                    NaN
# Popolazionefine periodo                                     -0.287056
#
# Regioni                                            Liguria  Emilia-Romagna  \
# 0
# Popolazioneinizio periodo                        -0.627010        0.003691
# Nati Vivi                                        -4.612403       -0.262243
# Morti                                             9.614669       10.029959
# SaldoNaturale                                    22.761461       36.478172
# Iscritti                                         -9.917487       -7.905435
# Cancellati                                       -3.211649       -1.971887
# Saldomigratorio e per altri motivi             -207.367150      -51.054384
# Unità inpiù/menodovute avariazioniterritoriali         NaN             NaN
# Popolazionefine periodo                          -0.658669       -0.022876
#
# Regioni                                           Toscana     Umbria  \
# 0
# Popolazioneinizio periodo                       -0.025300  -0.278596
# Nati Vivi                                       -4.555070  -7.376807
# Morti                                           11.454759  10.219823
# SaldoNaturale                                   43.465388  43.405676
# Iscritti                                        -8.227191  -5.889861
# Cancellati                                      -2.382869  -4.186508
# Saldomigratorio e per altri motivi             -51.197358 -25.225225
# Unità inpiù/menodovute avariazioniterritoriali        NaN        NaN
# Popolazionefine periodo                         -0.055532  -0.297315
#
# Regioni                                             Marche       Lazio  \
# 0
# Popolazioneinizio periodo                        -0.217831    0.271190
# Nati Vivi                                        -3.086315   -1.082269
# Morti                                            10.203129    7.594496
# SaldoNaturale                                    39.565380   59.268234
# Iscritti                                         -9.798052   -6.740171
# Cancellati                                       -0.467482   13.573741
# Saldomigratorio e per altri motivi             -760.330579 -109.236742
# Unità inpiù/menodovute avariazioniterritoriali         NaN         NaN
# Popolazionefine periodo                          -0.248996    0.221881
#
# Regioni                                            Abruzzo      Molise  \
# 0
# Popolazioneinizio periodo                        -0.231030   -0.337209
# Nati Vivi                                        -2.527925    2.380952
# Morti                                             6.498440    4.953076
# SaldoNaturale                                    26.807760    8.064516
# Iscritti                                         -9.605224   20.531654
# Cancellati                                       -2.104356   -1.113232
# Saldomigratorio e per altri motivi             -215.177066 -218.245614
# Unità inpiù/menodovute avariazioniterritoriali         NaN         NaN
# Popolazionefine periodo                          -0.254640   -0.308112
#
# Regioni                                           Campania     Puglia  \
# 0
# Popolazioneinizio periodo                        -0.176308  -0.036250
# Nati Vivi                                         0.931393  -4.689989
# Morti                                            11.917640   7.987254
# SaldoNaturale                                   107.683943  65.652174
# Iscritti                                         -4.808519  -5.038421
# Cancellati                                       -4.945562  -2.778026
# Saldomigratorio e per altri motivi              -29.016787  44.364821
# Unità inpiù/menodovute avariazioniterritoriali         NaN        NaN
# Popolazionefine periodo                          -0.184420  -0.048271
#
# Regioni                                         Basilicata     Calabria  \
# 0
# Popolazioneinizio periodo                        -0.329453    -0.237998
# Nati Vivi                                        -0.050125     2.923217
# Morti                                             8.025890     7.285488
# SaldoNaturale                                    22.739726    21.165771
# Iscritti                                         -2.421796    -9.610759
# Cancellati                                       -3.988013    -5.463998
# Saldomigratorio e per altri motivi              -20.588235  5626.666667
# Unità inpiù/menodovute avariazioniterritoriali         NaN          NaN
# Popolazionefine periodo                          -0.334558    -0.249467
#
# Regioni                                            Sicilia    Sardegna
# 0
# Popolazioneinizio periodo                        -0.098321   -0.091194
# Nati Vivi                                        -2.445523   -3.150610
# Morti                                             7.927900    7.433260
# SaldoNaturale                                    50.116099   29.158879
# Iscritti                                         -8.687516  -15.856549
# Cancellati                                       -4.179178   -8.140771
# Saldomigratorio e per altri motivi              293.503185 -139.426523
# Unità inpiù/menodovute avariazioniterritoriali         NaN         NaN
# Popolazionefine periodo                          -0.114363   -0.114626

# %%
(Isem2015 / Isem2014 * 100 - 100).loc["Morti"]
# Out:
# Regioni
# Piemonte                        10.957292
# Valle d'Aosta/Vallée d'Aoste    18.475073
# Lombardia                       10.332855
# Trentino-Alto Adige              9.842863
# Veneto                          10.339194
# Friuli-Venezia Giulia           12.301876
# Liguria                          9.614669
# Emilia-Romagna                  10.029959
# Toscana                         11.454759
# Umbria                          10.219823
# Marche                          10.203129
# Lazio                            7.594496
# Abruzzo                          6.498440
# Molise                           4.953076
# Campania                        11.917640
# Puglia                           7.987254
# Basilicata                       8.025890
# Calabria                         7.285488
# Sicilia                          7.927900
# Sardegna                         7.433260
# Name: Morti, dtype: float64
